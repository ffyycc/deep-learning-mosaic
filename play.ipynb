# %%
import matplotlib.pyplot as plt2
import numpy as np
from keras.models import load_model
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
# Load the model
model = load_model('cnn.h5')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
def classify_image(img_path):
    img = image.load_img(img_path, target_size=(32, 32))

    # Convert the image to a numpy array
    x = image.img_to_array(img)

    # Normalize the image
    x = x / 255.0

    # Add a dimension to transform the array into a "batch" of size (1, 32, 32, 3)
    x = np.expand_dims(x, axis=0)

    # Perform the prediction
    preds = model.predict(x)

    # Decode the prediction
    pred_class = np.argmax(preds[0])

    # Map the label index to the corresponding class
    label_map = {0: 'Cat', 1: 'Dog', 2: 'Airplane', 3: 'Automobile'}  # adjust this to your classes
    print(f'The image is classified as: {label_map[pred_class]}')

    imgplot = plt.imshow(img)
    plt.show()

# %%
# Load the image
img_path = 'test_images/bonnie.jpeg'
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 10ms/step
# The image is classified as: Dog

# %%
img_path = 'test_images/yucheng.png'  # replace with your image path
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 12ms/step
# The image is classified as: Cat

# %%
# Load the image
img_path = 'test_images/licheng.JPG' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 9ms/step
# The image is classified as: Cat

# %%
# Load the image
img_path = 'test_images/boss.png' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# The image is classified as: Dog

# %%
# Load the image
img_path = 'test_images/shirley.jpeg' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 10ms/step
# The image is classified as: Dog

# %%
# Load the image
img_path = 'test_images/dog_test.png' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 9ms/step
# The image is classified as: Cat

# %%
# Load the image
img_path = 'test_images/cat_test.png' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 12ms/step
# The image is classified as: Cat

# %%
# Load the image
img_path = 'test_images/cat_test2.png' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 13ms/step
# The image is classified as: Cat

# %%
# Load the image
img_path = 'test_images/dog_test2.png' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 9ms/step
# The image is classified as: Dog

# %%
# Load the image
img_path = 'test_images/cat_test3.png' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 14ms/step
# The image is classified as: Dog

# %%
# Load the image
img_path = 'test_images/cat_test4.png' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 13ms/step
# The image is classified as: Dog

# %%
img_path = 'test_images/cat_test5.png' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 11ms/step
# The image is classified as: Dog

# %%
img_path = 'test_images/cat_test6.png' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 10ms/step
# The image is classified as: Cat

# %%
img_path = 'test_images/dog_test3.png' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 14ms/step
# The image is classified as: Cat

# %%
img_path = 'test_images/dog_test4.png' 
classify_image(img_path)
# Out:
# 1/1 [==============================] - 0s 10ms/step
# The image is classified as: Automobile
